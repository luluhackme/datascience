# %%
import pandas as pd

# %%
spotify_data = {
    "Title": [
        "Blinding Lights",
        "Shape of You",
        "As It Was",
        "Someone Like You",
        "Levitating",
        "Bad Guy",
        "Stay",
        "Dance Monkey",
        "Rockstar",
        "One Dance",
        "Closer",
        "Perfect"
    ],
    "Artist": [
        "The Weeknd",
        "Ed Sheeran",
        "Harry Styles",
        "Adele",
        "Dua Lipa",
        "Billie Eilish",
        "The Kid LAROI & Justin Bieber",
        "Tones and I",
        "Post Malone",
        "Drake",
        "The Chainsmokers",
        "Ed Sheeran"
    ],
    "Album": [
        "After Hours",
        "Divide",
        "Harry's House",
        "21",
        "Future Nostalgia",
        "When We All Fall Asleep, Where Do We Go?",
        "Stay (Single)",
        "The Kids Are Coming",
        "Beerbongs & Bentleys",
        "Views",
        "Collage",
        "Divide"
    ],
    "Streams (Millions)": [
        3800,
        3500,
        2500,
        2200,
        2100,
        2000,
        1950,
        1900,
        1850,
        1800,
        1750,
        1700
    ],
    "Release Year": [
        2019,
        2017,
        2022,
        2011,
        2020,
        2019,
        2021,
        2019,
        2018,
        2016,
        2016,
        2017
    ],
    "Genre": [
        "Pop",
        "Pop",
        "Pop",
        "Soul",
        "Pop",
        "Electropop",
        "Pop",
        "Pop",
        "Hip-Hop",
        "Dancehall",
        "EDM",
        "Pop"
    ]
}

# %%
df = pd.DataFrame(spotify_data)

# %%
df
# Out:
#                Title                         Artist  \
# 0    Blinding Lights                     The Weeknd
# 1       Shape of You                     Ed Sheeran
# 2          As It Was                   Harry Styles
# 3   Someone Like You                          Adele
# 4         Levitating                       Dua Lipa
# 5            Bad Guy                  Billie Eilish
# 6               Stay  The Kid LAROI & Justin Bieber
# 7       Dance Monkey                    Tones and I
# 8           Rockstar                    Post Malone
# 9          One Dance                          Drake
# 10            Closer               The Chainsmokers
# 11           Perfect                     Ed Sheeran
#
#                                        Album  Streams (Millions)  \
# 0                                After Hours                3800
# 1                                     Divide                3500
# 2                              Harry's House                2500
# ...

# %%
df.sort_values(by=["Release Year"], ascending=True)
# Out:
#                Title                         Artist  \
# 3   Someone Like You                          Adele
# 9          One Dance                          Drake
# 10            Closer               The Chainsmokers
# 1       Shape of You                     Ed Sheeran
# 11           Perfect                     Ed Sheeran
# 8           Rockstar                    Post Malone
# 0    Blinding Lights                     The Weeknd
# 5            Bad Guy                  Billie Eilish
# 7       Dance Monkey                    Tones and I
# 4         Levitating                       Dua Lipa
# 6               Stay  The Kid LAROI & Justin Bieber
# 2          As It Was                   Harry Styles
#
#                                        Album  Streams (Millions)  \
# 3                                         21                2200
# 9                                      Views                1800
# 10                                   Collage                1750
# ...

# %%
df[(df['Artist'] == 'Ed Sheeran') | (df['Streams (Millions)'] > 3000)]
# Out:
#               Title      Artist        Album  Streams (Millions)  \
# 0   Blinding Lights  The Weeknd  After Hours                3800
# 1      Shape of You  Ed Sheeran       Divide                3500
# 11          Perfect  Ed Sheeran       Divide                1700
#
#     Release Year Genre
# 0           2019   Pop
# 1           2017   Pop
# 11          2017   Pop
