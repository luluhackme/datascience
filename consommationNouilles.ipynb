# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/refs/heads/master/2015_Instant_Noodle_Consumption_Around_the_World.csv')

# %%
df.columns
# Out:
# Index(['Location', ' Servings'], dtype='object')

# %%
df = pd.read_csv(r'C:\Users\micro\Documents\txt\noodle.csv')

# %%
df
# Out:
#           Location  Servings
# 0   China&HongKong     40430
# 1        Indonesia     13200
# 2            Japan      5540
# 3          Vietnam      4800
# 4              USA      4210
# 5            Korea      3650
# 6      Philippines      3480
# 7            India      3260
# 8         Thailand      3070
# 9           Brazil      2280
# 10          Russia      1840
# 11         Nigeria      1540
# 12        Malaysia      1360
# 13           Nepal      1190
# 14          Mexico       830

# %%
fig, ax = plt.subplots(2, 1, figsize=(15,40))

ax[0].bar(df['Location'], df['Servings'])
ax[0].set_xlabel('Pays')
ax[0].set_ylabel('Quantité')
ax[0].set_title('Consommation de nouilles instantanées en fonction du pays')
ax[1].pie(df['Servings'], labels=df['Location'], autopct='%1.1f%%')

plt.show()
