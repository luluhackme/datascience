# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/refs/heads/master/2014_usa_states.csv')

# %%
df
# Out:
#     Rank                 State Postal  Population
# 0      1               Alabama     AL   4849377.0
# 1      2                Alaska     AK    736732.0
# 2      3               Arizona     AZ   6731484.0
# 3      4              Arkansas     AR   2966369.0
# 4      5            California     CA  38802500.0
# 5      6              Colorado     CO   5355866.0
# 6      7           Connecticut     CT   3596677.0
# 7      8              Delaware     DE    935614.0
# 8      9  District of Columbia     DC    658893.0
# 9     10               Florida     FL  19893297.0
# 10    11               Georgia     GA  10097343.0
# 11    12                Hawaii     HI   1419561.0
# 12    13                 Idaho     ID   1634464.0
# 13    14              Illinois     IL  12880580.0
# 14    15               Indiana     IN   6596855.0
# 15    16                  Iowa     IA   3107126.0
# 16    17                Kansas     KS   2904021.0
# 17    18              Kentucky     KY   4413457.0
# ...

# %%
fig, ax = plt.subplots(figsize=(80,6))

ax.bar(df['State'], df['Population'])
ax.set_title('Population by U.S States in 2014')
ax.set_xlabel('State')
ax.set_ylabel('Population')

plt.show()

# %%
df2 = pd.read_csv(r'C:\Users\micro\Documents\datasets\electoralCollege.csv')

# %%
df2
# Out:
#              State  nbVoters
# 0          Alabama         9
# 1           Alaska         3
# 2          Arizona        11
# 3         Arkansas         6
# 4       California        54
# 5         Colorado        10
# 6      Connecticut         7
# 7         Delaware         3
# 8         Columbia         3
# 9          Florida        30
# 10         Georgia        16
# 11          Hawaii         4
# 12           Idaho         4
# 13        Illinois        19
# 14         Indiana        11
# 15            Iowa         6
# 16          Kansas         6
# 17        Kentucky         8
# 18       Louisiana         8
# 19           Maine         4
# 20        Maryland        10
# 21   Massachusetts        11
# 22        Michigan        15
# 23       Minnesota        10
# 24     Mississippi         6
# 25        Missouri        10
# 26         Montana         4
# 27        Nebraska         5
# 28          Nevada         6
# 29   New Hampshire         4
# 30      New Jersey        14
# ...

# %%
fig, axes = plt.subplots(2, 1, figsize=(80,6), sharex=True)

axes[0].bar(df['State'], df['Population'], color='red')
axes[0].set_title('Population by U.S States in 2014')
axes[0].set_ylabel('Population')

axes[1].bar(df2['State'], df2['nbVoters'])
axes[1].set_title('Electoral College Allocation (2020)')
axes[1].set_ylabel('Votes count')

plt.xlabel('State')

plt.show()
